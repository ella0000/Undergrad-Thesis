# %% [markdown]
# # QSAR 모델 개발 및 Ligand-based Virtual Screening

# %% [markdown]
# - Input : Smiles
# - Feature : ECFP
# - Target Values : pChEMBL Value (pIC50)
# - Models : Regression model
#      - RandomForestRegression
#      - FNN(pytorch)
#      - Loss : MSE
# - Model selection : validation set

# %% [markdown]
# ## 1. 데이터 전처리

# %%
import rdkit
from rdkit import Chem
from rdkit.Chem import AllChem
import deepchem
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import sklearn
from rdkit.Chem.rdFingerprintGenerator import GetMorganGenerator
# Out:
# WARNING:tensorflow:From C:\Users\USER\anaconda3\Lib\site-packages\tensorflow\python\util\deprecation.py:588: calling function (from tensorflow.python.eager.polymorphic_function.polymorphic_function) with experimental_relax_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# experimental_relax_shapes is deprecated, use reduce_retracing instead

# %%
raw_chembl_df = pd.read_csv("LRRK2_ChEMBL.csv", sep = ';', encoding='utf-8')

# %%
raw_chembl_df
# Out:
#      Molecule ChEMBL ID Molecule Name  Molecule Max Phase  Molecular Weight  \
# 0         CHEMBL2348984           NaN                 NaN            355.32
# 1         CHEMBL2348982           NaN                 NaN            450.47
# 2         CHEMBL2348967           NaN                 NaN            395.39
# 3         CHEMBL2348962           NaN                 NaN            390.29
# 4         CHEMBL2348956           NaN                 NaN            336.34
# ...                 ...           ...                 ...               ...
# 2633      CHEMBL5169734           NaN                 NaN            325.38
# 2634      CHEMBL5179942           NaN                 NaN            351.41
# 2635      CHEMBL5185049           NaN                 NaN            337.34
# 2636      CHEMBL5189805           NaN                 NaN            341.37
# 2637      CHEMBL5189165           NaN                 NaN            342.40
#
#       #RO5 Violations  AlogP Compound Key  \
# 0                   0   4.55           51
# 1                   1   5.20           49
# 2                   0   4.30           33
# 3                   0   4.16           28
# 4                   0   4.17           21
# ...               ...    ...          ...
# 2633                0   4.55           19
# 2634                0   4.60           50
# 2635                0   4.16           14
# 2636                0   4.25           18
# 2637                0   4.56           48
#
#                                                  Smiles Standard Type  \
# 0           FC(F)(F)c1cccc(Nc2ccc3nnc(-c4ccccc4)n3n2)c1          IC50
# 1     CCOC(=O)c1cc(Sc2cccc(C(F)(F)F)c2)nn2c(-c3cccs3...          IC50
# 2           FC(F)(F)Oc1cccc(Sc2ccc3nnc(-c4cncs4)n3n2)c1          IC50
# 3                  Brc1cccc(Sc2ccc3nnc(-c4cncs4)n3n2)c1          IC50
# 4               FC(F)(F)c1cccc(Sc2ccc3nnc(C4CC4)n3n2)c1          IC50
# ...                                                 ...           ...
# 2633         Cc1cccc(Nc2ccc3[nH]nc(-c4ccncc4)c3c2)c1C#N          IC50
# 2634     N#Cc1ccc2c(c1)CCC2Nc1ccc2[nH]nc(-c3ccncc3)c2c1          IC50
# 2635     N#Cc1ccc(Oc2ccc3[nH]nc(-c4ccncc4)c3c2)c(C#N)c1          IC50
# 2636      COc1ccc(C#N)c(Nc2ccc3[nH]nc(-c4ccncc4)c3c2)c1          IC50
# 2637       c1ccc2c(c1)OCCC2Nc1ccc2[nH]nc(-c3ccncc3)c2c1          IC50
#
#      Standard Relation  ...     Target Type Document ChEMBL ID  Source ID  \
# 0                  '>'  ...  SINGLE PROTEIN      CHEMBL2346543          1
# 1                  '>'  ...  SINGLE PROTEIN      CHEMBL2346543          1
# 2                  '='  ...  SINGLE PROTEIN      CHEMBL2346543          1
# 3                  '='  ...  SINGLE PROTEIN      CHEMBL2346543          1
# 4                  '='  ...  SINGLE PROTEIN      CHEMBL2346543          1
# ...                ...  ...             ...                ...        ...
# 2633               '='  ...  SINGLE PROTEIN      CHEMBL5154686          1
# 2634               '='  ...  SINGLE PROTEIN      CHEMBL5154686          1
# 2635               '='  ...  SINGLE PROTEIN      CHEMBL5154686          1
# 2636               '='  ...  SINGLE PROTEIN      CHEMBL5154686          1
# 2637               '='  ...  SINGLE PROTEIN      CHEMBL5154686          1
#
#          Source Description      Document Journal Document Year  \
# 0     Scientific Literature  Bioorg Med Chem Lett          2013
# 1     Scientific Literature  Bioorg Med Chem Lett          2013
# 2     Scientific Literature  Bioorg Med Chem Lett          2013
# 3     Scientific Literature  Bioorg Med Chem Lett          2013
# 4     Scientific Literature  Bioorg Med Chem Lett          2013
# ...                     ...                   ...           ...
# 2633  Scientific Literature        Eur J Med Chem          2022
# 2634  Scientific Literature        Eur J Med Chem          2022
# 2635  Scientific Literature        Eur J Med Chem          2022
# 2636  Scientific Literature        Eur J Med Chem          2022
# 2637  Scientific Literature        Eur J Med Chem          2022
#
#       Cell ChEMBL ID  Properties  Action Type  Standard Text Value
# 0                NaN         NaN          NaN                  NaN
# 1                NaN         NaN          NaN                  NaN
# 2                NaN         NaN          NaN                  NaN
# 3                NaN         NaN          NaN                  NaN
# 4                NaN         NaN          NaN                  NaN
# ...              ...         ...          ...                  ...
# 2633             NaN         NaN    INHIBITOR                  NaN
# 2634             NaN         NaN    INHIBITOR                  NaN
# 2635             NaN         NaN    INHIBITOR                  NaN
# 2636             NaN         NaN    INHIBITOR                  NaN
# 2637             NaN         NaN    INHIBITOR                  NaN
#
# [2638 rows x 47 columns]

# %%
raw_chembl_df.describe()
# Out:
#        Molecule Max Phase  Molecular Weight  #RO5 Violations        AlogP  \
# count            3.000000       2638.000000      2638.000000  2638.000000
# mean             3.666667        367.809151         0.077331     3.130686
# std              0.577350         65.360836         0.292897     1.010777
# min              3.000000        135.130000         0.000000    -0.110000
# 25%              3.500000        325.380000         0.000000     2.510000
# 50%              4.000000        368.440000         0.000000     3.090000
# 75%              4.000000        406.490000         0.000000     3.740000
# max              4.000000        727.910000         2.000000     6.900000
#
#        Standard Value  pChEMBL Value  Ligand Efficiency BEI  \
# count     2571.000000    2441.000000            2427.000000
# mean      1327.403884       7.230258              20.240886
# std       7409.463689       0.966685               3.774034
# min          0.001000       4.040000               8.880000
# 25%         12.590000       6.620000              17.720000
# 50%         52.000000       7.290000              20.040000
# 75%        264.500000       7.890000              22.530000
# max     101080.000000      10.190000              37.480000
#
#        Ligand Efficiency LE  Ligand Efficiency LLE  Ligand Efficiency SEI  \
# count           2427.000000            2425.000000            2427.000000
# mean               0.379131               4.113192               9.261001
# std                0.067665               1.357443               2.634694
# min                0.160000              -0.850000               3.860000
# 25%                0.330000               3.240000               7.395000
# 50%                0.380000               4.200000               8.890000
# 75%                0.420000               5.100000              10.730000
# max                0.700000               8.210000              34.000000
#
#        Potential Duplicate  Assay Tissue ChEMBL ID  Assay Tissue Name  \
# count          2638.000000                     0.0                0.0
# mean              0.027293                     NaN                NaN
# std               0.162968                     NaN                NaN
# min               0.000000                     NaN                NaN
# 25%               0.000000                     NaN                NaN
# 50%               0.000000                     NaN                NaN
# 75%               0.000000                     NaN                NaN
# max               1.000000                     NaN                NaN
#
#        Assay Subcellular Fraction    Source ID  Document Year  \
# count                         0.0  2638.000000    2638.000000
# mean                          NaN    14.073161    2016.894617
# std                           NaN    17.501686       2.849845
# min                           NaN     1.000000    2011.000000
# 25%                           NaN     1.000000    2015.000000
# 50%                           NaN     1.000000    2016.000000
# 75%                           NaN    37.000000    2019.000000
# max                           NaN    65.000000    2023.000000
#
#        Standard Text Value
# count                  0.0
# mean                   NaN
# std                    NaN
# min                    NaN
# 25%                    NaN
# 50%                    NaN
# 75%                    NaN
# max                    NaN

# %%
raw_chembl_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2638 entries, 0 to 2637
# Data columns (total 47 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Molecule ChEMBL ID          2638 non-null   object
#  1   Molecule Name               31 non-null     object
#  2   Molecule Max Phase          3 non-null      float64
#  3   Molecular Weight            2638 non-null   float64
#  4   #RO5 Violations             2638 non-null   int64
#  5   AlogP                       2638 non-null   float64
#  6   Compound Key                2638 non-null   object
#  7   Smiles                      2638 non-null   object
#  8   Standard Type               2638 non-null   object
#  9   Standard Relation           2564 non-null   object
#  10  Standard Value              2571 non-null   float64
#  11  Standard Units              2571 non-null   object
#  12  pChEMBL Value               2441 non-null   float64
#  13  Data Validity Comment       3 non-null      object
#  14  Comment                     1009 non-null   object
#  15  Uo Units                    2571 non-null   object
#  16  Ligand Efficiency BEI       2427 non-null   float64
#  17  Ligand Efficiency LE        2427 non-null   float64
#  18  Ligand Efficiency LLE       2425 non-null   float64
#  19  Ligand Efficiency SEI       2427 non-null   float64
#  20  Potential Duplicate         2638 non-null   int64
#  21  Assay ChEMBL ID             2638 non-null   object
#  22  Assay Description           2638 non-null   object
#  23  Assay Type                  2638 non-null   object
#  24  BAO Format ID               2638 non-null   object
#  25  BAO Label                   2638 non-null   object
#  26  Assay Organism              1940 non-null   object
#  27  Assay Tissue ChEMBL ID      0 non-null      float64
#  28  Assay Tissue Name           0 non-null      float64
#  29  Assay Cell Type             371 non-null    object
#  30  Assay Subcellular Fraction  0 non-null      float64
#  31  Assay Parameters            11 non-null     object
#  32  Assay Variant Accession     824 non-null    object
#  33  Assay Variant Mutation      824 non-null    object
#  34  Target ChEMBL ID            2638 non-null   object
#  35  Target Name                 2638 non-null   object
#  36  Target Organism             2638 non-null   object
#  37  Target Type                 2638 non-null   object
#  38  Document ChEMBL ID          2638 non-null   object
#  39  Source ID                   2638 non-null   int64
#  40  Source Description          2638 non-null   object
#  41  Document Journal            1688 non-null   object
#  42  Document Year               2638 non-null   int64
#  43  Cell ChEMBL ID              213 non-null    object
#  44  Properties                  517 non-null    object
#  45  Action Type                 595 non-null    object
#  46  Standard Text Value         0 non-null      float64
# dtypes: float64(13), int64(4), object(30)
# memory usage: 968.8+ KB

# %%
df = raw_chembl_df[['Smiles', 'pChEMBL Value']].copy(deep=True)
df.head()
# Out:
#                                               Smiles  pChEMBL Value
# 0        FC(F)(F)c1cccc(Nc2ccc3nnc(-c4ccccc4)n3n2)c1            NaN
# 1  CCOC(=O)c1cc(Sc2cccc(C(F)(F)F)c2)nn2c(-c3cccs3...            NaN
# 2        FC(F)(F)Oc1cccc(Sc2ccc3nnc(-c4cncs4)n3n2)c1           7.17
# 3               Brc1cccc(Sc2ccc3nnc(-c4cncs4)n3n2)c1           8.22
# 4            FC(F)(F)c1cccc(Sc2ccc3nnc(C4CC4)n3n2)c1           6.51

# %% [markdown]
# ### pChEMBL Value 결측치 제거

# %%
df.describe(include='all')
# Out:
#                                       Smiles  pChEMBL Value
# count                                   2638    2441.000000
# unique                                  1524            NaN
# top     Cc1cccc(-c2cc(N)nc3[nH]cc(C#N)c23)c1            NaN
# freq                                      17            NaN
# mean                                     NaN       7.230258
# std                                      NaN       0.966685
# min                                      NaN       4.040000
# 25%                                      NaN       6.620000
# 50%                                      NaN       7.290000
# 75%                                      NaN       7.890000
# max                                      NaN      10.190000

# %% [markdown]
# * Smiles > pChEMBL Value : pChEMBL Value 결측치가 존재한다
# * 따라서 결측치 제거 필요

# %%
df = df.dropna(subset = ['pChEMBL Value'])
df.describe(include = 'all')
# Out:
#                                       Smiles  pChEMBL Value
# count                                   2441    2441.000000
# unique                                  1426            NaN
# top     Cc1cccc(-c2cc(N)nc3[nH]cc(C#N)c23)c1            NaN
# freq                                      16            NaN
# mean                                     NaN       7.230258
# std                                      NaN       0.966685
# min                                      NaN       4.040000
# 25%                                      NaN       6.620000
# 50%                                      NaN       7.290000
# 75%                                      NaN       7.890000
# max                                      NaN      10.190000

# %% [markdown]
# * Smiles와 pChEMBL Value의 count 값이 같이졌다

# %% [markdown]
# ### Smiles - pChEMBL 중복 값 제거

# %%
# 중복 줄 확인
df[df.duplicated(keep=False)]
# Out:
#                                                  Smiles  pChEMBL Value
# 35    C[C@@H]1CN(c2cc(-c3n[nH]c4ccc(OC5(C)CC5)cc34)n...           9.12
# 36          CC(C)Oc1ccc2[nH]nc(-c3cc(N4CCOCC4)ncn3)c2c1           7.02
# 37    COc1cc(C(=O)N2CCC(N3CCN(C)CC3)CC2)ccc1Nc1ncc2c...           8.22
# 58    COC[C@H](C)Oc1ccc2[nH]nc(-c3cc(N4CCC5(CC4)CNC(...           8.54
# 59    COC[C@H](C)Oc1ccc2[nH]nc(-c3cc(N4CCO[C@H](C)C4...           8.55
# ...                                                 ...            ...
# 2386   C[C@@H]1CCCN1c1c(C#N)c2c(N)nc(Nc3cn[nH]c3)nc2n1C           8.22
# 2404  COC[C@H](C)Oc1ccc2[nH]nc(-c3cc(N4CCO[C@H](C)C4...           8.55
# 2427  C[C@@H]1CN(c2cc(-c3n[nH]c4ccc(OC5(C)CC5)cc34)n...           9.00
# 2453  C[C@H]1CC1(C#N)c1ccc2cnn(-c3cc(N4CC5(C(C)(C)O)...           8.70
# 2514  C[C@@H]1CN(c2cc(-c3n[nH]c4ccc(OC5(C)CC5)cc34)n...           9.40
#
# [222 rows x 2 columns]

# %%
# (Smiles, pChEMBL Value)가 중복인 줄은 첫 번째 값만 남기고 나머지는 제거
df = df.drop_duplicates()
df.head()
# Out:
#                                            Smiles  pChEMBL Value
# 2     FC(F)(F)Oc1cccc(Sc2ccc3nnc(-c4cncs4)n3n2)c1           7.17
# 3            Brc1cccc(Sc2ccc3nnc(-c4cncs4)n3n2)c1           8.22
# 4         FC(F)(F)c1cccc(Sc2ccc3nnc(C4CC4)n3n2)c1           6.51
# 5  Fc1ccc(-c2nnc3ccc(Sc4cccc(C(F)(F)F)c4)nn23)cc1           6.75
# 6             COC(=O)C(C)Sc1ccc2ncc(-c3cccs3)n2n1           8.00

# %% [markdown]
# ### 중복된 Smiles 처리

# %%
df.describe(include = 'all')
# Out:
#                                       Smiles  pChEMBL Value
# count                                   2328    2328.000000
# unique                                  1426            NaN
# top     Cc1cccc(-c2cc(N)nc3[nH]cc(C#N)c23)c1            NaN
# freq                                      11            NaN
# mean                                     NaN       7.216147
# std                                      NaN       0.971040
# min                                      NaN       4.040000
# 25%                                      NaN       6.610000
# 50%                                      NaN       7.280000
# 75%                                      NaN       7.890000
# max                                      NaN      10.190000

# %% [markdown]
# * count > unique : Smiles가 똑같은 줄이 있다
# * Smiles는 똑같은데 pChEMBL Value가 다른 데이터에 대해서는 pChEMBL Value를 평균 내어서 넣어줌

# %%
# Smiles가 중복되는 줄 모두 가져오기
df_dup = df[df.duplicated(subset = ['Smiles'], keep=False)].copy(deep=False)
df_dup
# Out:
#                                               Smiles  pChEMBL Value
# 2        FC(F)(F)Oc1cccc(Sc2ccc3nnc(-c4cncs4)n3n2)c1           7.17
# 3               Brc1cccc(Sc2ccc3nnc(-c4cncs4)n3n2)c1           8.22
# 4            FC(F)(F)c1cccc(Sc2ccc3nnc(C4CC4)n3n2)c1           6.51
# 5     Fc1ccc(-c2nnc3ccc(Sc4cccc(C(F)(F)F)c4)nn23)cc1           6.75
# 6                COC(=O)C(C)Sc1ccc2ncc(-c3cccs3)n2n1           8.00
# ...                                              ...            ...
# 2633      Cc1cccc(Nc2ccc3[nH]nc(-c4ccncc4)c3c2)c1C#N           7.42
# 2634  N#Cc1ccc2c(c1)CCC2Nc1ccc2[nH]nc(-c3ccncc3)c2c1           7.40
# 2635  N#Cc1ccc(Oc2ccc3[nH]nc(-c4ccncc4)c3c2)c(C#N)c1           7.32
# 2636   COc1ccc(C#N)c(Nc2ccc3[nH]nc(-c4ccncc4)c3c2)c1           6.43
# 2637    c1ccc2c(c1)OCCC2Nc1ccc2[nH]nc(-c3ccncc3)c2c1           7.38
#
# [1592 rows x 2 columns]

# %%
# Smiles 기준으로 mean()을 사용해서 각 group 마다 pChEMBL Value의 평균값 구하기
df_mean = df_dup.groupby(by='Smiles').mean().reset_index()
df_mean
# Out:
#                                              Smiles  pChEMBL Value
# 0              Brc1cccc(Sc2ccc3nnc(-c4cncs4)n3n2)c1       7.296667
# 1           Brc1cncc(-c2c[nH]c3ncnc(N4CCOCC4)c23)c1       8.035000
# 2             C1=C(c2c[nH]c3ncnc(N4CCOCC4)c23)CCCO1       6.950000
# 3             C1=C(c2c[nH]c3ncnc(N4CCOCC4)c23)COCC1       6.735000
# 4    C=CS(=O)(=O)Nc1cccc(Nc2ncnc3cc(OC)c(OC)cc23)c1       7.005000
# ..                                              ...            ...
# 685      c1cnc2c(-c3c[nH]c4ncnc(N5CCOCC5)c34)cnn2c1       7.185000
# 686           c1cncc(-c2c[nH]c3ncnc(N4CCOCC4)c23)c1       7.130000
# 687      c1cnn2c(-c3c[nH]c4ncnc(N5CCOCC5)c34)cnc2c1       8.055000
# 688         c1nc(N2CCOCC2)c2c(-c3cn[nH]c3)c[nH]c2n1       7.540000
# 689       c1nc(N2CCOCC2)c2c(-c3cnc4sccn34)c[nH]c2n1       7.510000
#
# [690 rows x 2 columns]

# %%
# Smiles 기준 중복인 줄 모두 제거
df_drop = df.drop_duplicates(subset = 'Smiles', keep = False).copy(deep = True)
df_drop.head()
# Out:
#                                             Smiles  pChEMBL Value
# 15  COc1ccc(OC)c(Sc2cc(C)c3nnc(-c4cnn(C)c4)n3n2)c1           4.50
# 16  COc1ccc(OC)c(C(O)c2ccc3nnc(-c4cnn(C)c4)n3n2)c1           5.04
# 17    COc1ccc(C(C)C)cc1Sc1ccc2nnc(-c3cnn(C)c3)n2n1           5.87
# 19       COc1ccc(OC)c(Sc2ccc3nnc(-c4cnccn4)n3n2)c1           6.06
# 20       COc1ccc(OC)c(Sc2ccc3nnc(-c4ccncc4)n3n2)c1           6.46

# %%
# 원래 데이터프레임에 (smiles, mean value) 데이터 추가
df = pd.concat([df_drop, df_mean])
df
# Out:
#                                              Smiles  pChEMBL Value
# 15   COc1ccc(OC)c(Sc2cc(C)c3nnc(-c4cnn(C)c4)n3n2)c1          4.500
# 16   COc1ccc(OC)c(C(O)c2ccc3nnc(-c4cnn(C)c4)n3n2)c1          5.040
# 17     COc1ccc(C(C)C)cc1Sc1ccc2nnc(-c3cnn(C)c3)n2n1          5.870
# 19        COc1ccc(OC)c(Sc2ccc3nnc(-c4cnccn4)n3n2)c1          6.060
# 20        COc1ccc(OC)c(Sc2ccc3nnc(-c4ccncc4)n3n2)c1          6.460
# ..                                              ...            ...
# 685      c1cnc2c(-c3c[nH]c4ncnc(N5CCOCC5)c34)cnn2c1          7.185
# 686           c1cncc(-c2c[nH]c3ncnc(N4CCOCC4)c23)c1          7.130
# 687      c1cnn2c(-c3c[nH]c4ncnc(N5CCOCC5)c34)cnc2c1          8.055
# 688         c1nc(N2CCOCC2)c2c(-c3cn[nH]c3)c[nH]c2n1          7.540
# 689       c1nc(N2CCOCC2)c2c(-c3cnc4sccn34)c[nH]c2n1          7.510
#
# [1426 rows x 2 columns]

# %%
df.describe(include = 'all')
# Out:
#                                                 Smiles  pChEMBL Value
# count                                             1426    1426.000000
# unique                                            1426            NaN
# top     COc1ccc(OC)c(Sc2cc(C)c3nnc(-c4cnn(C)c4)n3n2)c1            NaN
# freq                                                 1            NaN
# mean                                               NaN       7.278293
# std                                                NaN       0.980570
# min                                                NaN       4.045000
# 25%                                                NaN       6.745000
# 50%                                                NaN       7.350000
# 75%                                                NaN       7.941250
# max                                                NaN      10.190000

# %% [markdown]
# * 이제 Smiles의 count와 unique의 값이 같아졌다.
# * 데이터 전처리 완료!

# %% [markdown]
# ### Column 이름 바꾸기
# pChEMBL -> pIC50으로 변경

# %%
df = df.rename(columns = {'pChEMBL Value' : 'pIC50'})
df
# Out:
#                                              Smiles  pIC50
# 15   COc1ccc(OC)c(Sc2cc(C)c3nnc(-c4cnn(C)c4)n3n2)c1  4.500
# 16   COc1ccc(OC)c(C(O)c2ccc3nnc(-c4cnn(C)c4)n3n2)c1  5.040
# 17     COc1ccc(C(C)C)cc1Sc1ccc2nnc(-c3cnn(C)c3)n2n1  5.870
# 19        COc1ccc(OC)c(Sc2ccc3nnc(-c4cnccn4)n3n2)c1  6.060
# 20        COc1ccc(OC)c(Sc2ccc3nnc(-c4ccncc4)n3n2)c1  6.460
# ..                                              ...    ...
# 685      c1cnc2c(-c3c[nH]c4ncnc(N5CCOCC5)c34)cnn2c1  7.185
# 686           c1cncc(-c2c[nH]c3ncnc(N4CCOCC4)c23)c1  7.130
# 687      c1cnn2c(-c3c[nH]c4ncnc(N5CCOCC5)c34)cnc2c1  8.055
# 688         c1nc(N2CCOCC2)c2c(-c3cn[nH]c3)c[nH]c2n1  7.540
# 689       c1nc(N2CCOCC2)c2c(-c3cnc4sccn34)c[nH]c2n1  7.510
#
# [1426 rows x 2 columns]

# %%
# 데이터프레임을 csv 파일로 저장
df.to_csv("ChEMBL_LRRK2_IC50.csv", index = True)
